# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.metrics import mean_squared_error, r2_score

# %%
df1=pd.read_csv('train.csv')
df1
# Out:
#        id                species   margin1   margin2   margin3   margin4  \
# 0       1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1       2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2       3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3       5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4       6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
# ..    ...                    ...       ...       ...       ...       ...
# 985  1575   Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906
# 986  1578            Acer_Pictum  0.001953  0.003906  0.021484  0.107420
# 987  1581     Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484
# 988  1582          Quercus_Rubra  0.000000  0.000000  0.046875  0.056641
# 989  1584         Quercus_Afares  0.023438  0.019531  0.031250  0.015625
#
#       margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# ...

# %%
df2=pd.read_csv('test.csv')
df2
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 0       4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625
# 1       7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672
# 2       9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000
# 3      12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000
# 4      13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000
# ..    ...       ...       ...       ...       ...       ...       ...
# 589  1576  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000
# 590  1577  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000
# 591  1579  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625
# 592  1580  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391
# 593  1583  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720
#
#       margin7   margin8   margin9  ...  texture55  texture56  texture57  \
# ...

# %%
df1.shape
# Out:
# (990, 194)

# %%
df2.shape
# Out:
# (594, 193)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Columns: 194 entries, id to texture64
# dtypes: float64(192), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Columns: 193 entries, id to texture64
# dtypes: float64(192), int64(1)
# memory usage: 895.8 KB

# %%
df1.describe()
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   990.000000  990.000000  990.000000  990.000000  990.000000
# mean    799.595960    0.017412    0.028539    0.031988    0.023280
# std     452.477568    0.019739    0.038855    0.025847    0.028411
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     415.250000    0.001953    0.001953    0.013672    0.005859
# 50%     802.500000    0.009766    0.011719    0.025391    0.013672
# 75%    1195.500000    0.025391    0.041016    0.044922    0.029297
# max    1584.000000    0.087891    0.205080    0.156250    0.169920
#
#           margin5     margin6     margin7     margin8     margin9  ...  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  ...
# mean     0.014264    0.038579    0.019202    0.001083    0.007167  ...
# std      0.018390    0.052030    0.017511    0.002743    0.008933  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
df2.describe()
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   594.000000  594.000000  594.000000  594.000000  594.000000
# mean    780.673401    0.017562    0.028425    0.031858    0.022556
# std     465.646977    0.019585    0.038351    0.025719    0.028797
# min       4.000000    0.000000    0.000000    0.000000    0.000000
# 25%     368.500000    0.001953    0.001953    0.013672    0.005859
# 50%     774.000000    0.009766    0.010743    0.023438    0.013672
# 75%    1184.500000    0.028809    0.041016    0.042969    0.027344
# max    1583.000000    0.085938    0.189450    0.167970    0.164060
#
#           margin5     margin6     margin7     margin8     margin9  ...  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  ...
# mean     0.014527    0.037497    0.019222    0.001085    0.007092  ...
# std      0.018029    0.051372    0.017122    0.002697    0.009515  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
dup_df1=df1.duplicated().any()
print("are there any duplicated volues in the data",dup_df1)
# Out:
# are there any duplicated volues in the data False

# %%
plt1 = plt.figure(figsize=(18, 13))
a1 = plt1.gca()

# Assuming df is your DataFrame
df1.hist(ax=a1, bins=18)

plt.show()
# Out:
# C:\Users\THIS\AppData\Local\Temp\ipykernel_13380\32025526.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df1.hist(ax=a1, bins=18)

# %%
from sklearn.preprocessing import LabelEncoder#categorical data to numericaldata
le=LabelEncoder()
df1['species']=le.fit_transform(df1['species'])

# %%
df1.head()
# Out:
#    id  species   margin1   margin2   margin3   margin4   margin5   margin6  \
# 0   1        3  0.007812  0.023438  0.023438  0.003906  0.011719  0.009766
# 1   2       49  0.005859  0.000000  0.031250  0.015625  0.025391  0.001953
# 2   3       65  0.005859  0.009766  0.019531  0.007812  0.003906  0.005859
# 3   5       94  0.000000  0.003906  0.023438  0.005859  0.021484  0.019531
# 4   6       84  0.005859  0.003906  0.048828  0.009766  0.013672  0.015625
#
#     margin7  margin8  ...  texture55  texture56  texture57  texture58  \
# 0  0.027344      0.0  ...   0.007812   0.000000   0.002930   0.002930
# 1  0.019531      0.0  ...   0.000977   0.000000   0.000000   0.000977
# 2  0.068359      0.0  ...   0.154300   0.000000   0.005859   0.000977
# 3  0.023438      0.0  ...   0.000000   0.000977   0.000000   0.000000
# 4  0.005859      0.0  ...   0.096680   0.000000   0.021484   0.000000
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# ...

# %%
df1.isnull().sum()
# Out:
# id           0
# species      0
# margin1      0
# margin2      0
# margin3      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 194, dtype: int64

# %%
df2.isna().sum()
# Out:
# id           0
# margin1      0
# margin2      0
# margin3      0
# margin4      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 193, dtype: int64

# %%
df1['species'].value_counts()
# Out:
# species
# 3     10
# 26    10
# 2     10
# 39    10
# 0     10
#       ..
# 12    10
# 88    10
# 27    10
# 36    10
# 91    10
# Name: count, Length: 99, dtype: int64

# %%
print(df1.corr())
#dataplot=sns.heatmap(df1.corr(),cmap='YlGnBu',annot=True)
#plt.show()
# Out:
#                  id   species   margin1   margin2   margin3   margin4  \
# id         1.000000  0.071345 -0.011673 -0.027565 -0.059533  0.001639
# species    0.071345  1.000000 -0.018265 -0.089907  0.182852  0.120366
# margin1   -0.011673 -0.018265  1.000000  0.806390 -0.182829 -0.297807
# margin2   -0.027565 -0.089907  0.806390  1.000000 -0.204640 -0.315953
# margin3   -0.059533  0.182852 -0.182829 -0.204640  1.000000  0.120042
# ...             ...       ...       ...       ...       ...       ...
# texture60 -0.000823 -0.016716  0.035072  0.081069 -0.019850 -0.052317
# texture61  0.026319  0.158581 -0.007581 -0.007057  0.084957  0.320644
# texture62  0.032873  0.079675 -0.033159 -0.037405 -0.081999 -0.073886
# texture63  0.024299  0.194908 -0.075171 -0.098957 -0.148193  0.050970
# texture64  0.035396  0.064154  0.030414 -0.029532  0.061780  0.014343
#
#             margin5   margin6   margin7   margin8  ...  texture55  texture56  \
# ...

# %%
X=df1.drop(['species'],axis=1)
y=df1['species']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20,random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (792, 193) (198, 193) (792,) (198,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(X_train.shape)
#       2 print(y_train.shape)
#
# NameError: name 'X_train' is not defined

# %%
print("the training r_sq is :%.2f"% rf.score(X_train,y_train))
# Out:
# the training r_sq is :1.00

# %%
y_pred=rf.predict(X_train)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
y_pred=rf.predict(X_train)
print(classification_report(y_train,y_pred))
print(confusion_matrix(y_train,y_pred))
print(accuracy_score(y_train,y_pred)*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00         7
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00         9
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00         9
#           10       1.00      1.00      1.00         6
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00         8
#           13       1.00      1.00      1.00         8
#           14       1.00      1.00      1.00         9
#           15       1.00      1.00      1.00         8
# ...

# %%
from sklearn.svm import SVR

# %%
svr=SVR().fit(X_train,y_train)

# %%
print("the training r_sq is :%.2f"% svr.score(X_train,y_train))
# Out:
# the training r_sq is :0.01

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,explained_variance_score

# %%
ytrain_pred=svr.predict(X_train)

# %%
print("the training r_sq is :%.2f"% r2_score(y_train,ytrain_pred))
# Out:
# the training r_sq is :0.01

# %%
print("the MAE is :%.2f"% mean_absolute_error(y_train,ytrain_pred))
# Out:
# the MAE is :24.47

# %%
print("the MSE is :%.2f"% mean_squared_error(y_train,ytrain_pred))
# Out:
# the MSE is :807.68

# %%
ytest_pred=svr.predict(X_test)

# %%
print(ytest_pred[:10])
# Out:
# [55.13741272 52.39929662 46.35606527 55.12648613 47.17180403 47.42177356
#  46.04958403 47.36207754 53.70601177 55.58317505]

# %%
print('the r_sq is :%.2f'% r2_score(y_test,ytest_pred))
# Out:
# the r_sq is :-0.05

# %%
print('the r_sq is :%.2f'% svr.score(X_test,y_test))
# Out:
# the r_sq is :-0.05
